# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[1,2,3],[2,3,3],[3,3,6]])
rand_mat = np.random.randint(0,10,(3,3))
rand_mat
# Out:
# array([[4, 7, 4],
#        [8, 6, 2],
#        [8, 7, 7]])

# %%
val , vect = np.linalg.eig(x)
xaxis=np.array(range(1,4))
val=np.sort(val)
print("Eigenvalues:")
print(val)


print("The Dot Products of the EigenVectors are:")
for i in range(3):
    j = i+1
    if i == 2:
        j=0
    print(int(np.dot(vect[i],vect[j])))
# Out:
# Eigenvalues:
# [-0.55345915  1.15326423  9.40019492]
# The Dot Products of the EigenVectors are:
# 0
# 0
# 0

# %%
val=np.sort(val)
col = ['g','r','b']
print(val)
plt.scatter(xaxis,val,marker='o',color=col)
plt.show()
# Out:
# [-0.55345915  1.15326423  9.40019492]
# <img src="data:image/png;base64,..." width="640">
