# %% [markdown]
# ## Lecture $28^{th}$ Jan

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
steps=10000
pos=[]
time = np.linspace(0,10,steps)
dt = time[1]-time[0]
cpos = 0
pe = []
ke = []
te = []
m = 1
cp = 10
cv = cp/m
k=10
def force(pos):
    return -k*pos

for i in range(steps) :
    cp = cp + force(cpos) * dt
    cv = cp/m
    cpos = cpos + cv*dt
    pos = np.append(pos,cpos)
    ke = np.append(ke,m*cv*cv/2)
    pe = np.append(pe,k*cpos*cpos/2)
    te = np.append(te,m*cv*cv/2+k*cpos*cpos/2)

# %%
plt.plot(time,pos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(time,te)
plt.plot(time,pe)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(time,te)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Argon Time

# %% [markdown]
# N atoms
#
# size of the cube be $A^3$
#
#
# Packing fraction of argon liq would be around 0.4

# %%
N = 10

cpos = np.random.random(size=(N))

# %%
cpos
# Out:
# array([0.07956687, 0.52499697, 0.36783099, 0.38731105, 0.44048801,
#        0.03362567, 0.94382089, 0.45035003, 0.67644251, 0.43711478])
